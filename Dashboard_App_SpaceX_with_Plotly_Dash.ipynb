# %% [markdown]
# # Dashboard Application with Plotly Dash

# %%
# !pip install packaging
# !pip install pandas dash
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib
# !pip install scikit-learn
# !pip install jupyter_dash
# !pip install httpx==0.20 dash plotly
# !pip install dash
# Out:
# Requirement already satisfied: packaging in c:\anaconda3\lib\site-packages (23.0)
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: dash in c:\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\anaconda3\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in c:\anaconda3\lib\site-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in c:\anaconda3\lib\site-packages (from pandas) (1.21.4)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\anaconda3\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\anaconda3\lib\site-packages (from dash) (5.13.0)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.12.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0; python_version < "3.10" in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (6.2.0)
# Requirement already satisfied: click>=8.0 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.1.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask>=1.0.4->dash) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in c:\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask>=1.0.4->dash) (4.5.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\anaconda3\lib\site-packages (from click>=8.0->Flask>=1.0.4->dash) (0.4.1)
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in c:\anaconda3\lib\site-packages (from pandas) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in c:\anaconda3\lib\site-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\anaconda3\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.12.0)
# Requirement already satisfied: numpy in c:\anaconda3\lib\site-packages (1.21.4)
# Requirement already satisfied: seaborn in c:\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: numpy>=1.9.3 in c:\anaconda3\lib\site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\anaconda3\lib\site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: scipy>=0.14.0 in c:\anaconda3\lib\site-packages (from seaborn) (1.2.1)
# Requirement already satisfied: pandas>=0.15.2 in c:\anaconda3\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (2.8.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (2.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (4.38.0)
# Requirement already satisfied: setuptools-scm>=4 in c:\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (7.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (1.0.1)
# Requirement already satisfied: pytz>=2017.3 in c:\anaconda3\lib\site-packages (from pandas>=0.15.2->seaborn) (2018.9)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->seaborn) (1.12.0)
# Requirement already satisfied: tomli>=1.0.0; python_version < "3.11" in c:\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib>=1.4.3->seaborn) (2.0.1)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib>=1.4.3->seaborn) (40.8.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib>=1.4.3->seaborn) (6.2.0)
# Requirement already satisfied: typing-extensions in c:\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib>=1.4.3->seaborn) (4.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->setuptools-scm>=4->matplotlib>=1.4.3->seaborn) (3.15.0)
# Requirement already satisfied: matplotlib in c:\anaconda3\lib\site-packages (3.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\anaconda3\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: setuptools-scm>=4 in c:\anaconda3\lib\site-packages (from matplotlib) (7.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda3\lib\site-packages (from matplotlib) (2.8.0)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda3\lib\site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda3\lib\site-packages (from matplotlib) (1.0.1)
# Requirement already satisfied: typing-extensions in c:\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib) (4.5.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib) (6.2.0)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib) (40.8.0)
# Requirement already satisfied: tomli>=1.0.0; python_version < "3.11" in c:\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.12.0)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->setuptools-scm>=4->matplotlib) (3.15.0)
# Requirement already satisfied: scikit-learn in c:\anaconda3\lib\site-packages (0.23.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.21.4)
# Requirement already satisfied: scipy>=0.19.1 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda3\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: jupyter_dash in c:\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: retrying in c:\anaconda3\lib\site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\anaconda3\lib\site-packages (from jupyter_dash) (1.5.6)
# Requirement already satisfied: flask in c:\anaconda3\lib\site-packages (from jupyter_dash) (2.2.3)
# Requirement already satisfied: ansi2html in c:\anaconda3\lib\site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from jupyter_dash) (2.26.0)
# Requirement already satisfied: dash in c:\anaconda3\lib\site-packages (from jupyter_dash) (2.9.1)
# Requirement already satisfied: ipython in c:\anaconda3\lib\site-packages (from jupyter_dash) (7.4.0)
# Requirement already satisfied: ipykernel in c:\anaconda3\lib\site-packages (from jupyter_dash) (5.1.0)
# Requirement already satisfied: six>=1.7.0 in c:\anaconda3\lib\site-packages (from retrying->jupyter_dash) (1.12.0)
# Requirement already satisfied: click>=8.0 in c:\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\anaconda3\lib\site-packages (from flask->jupyter_dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0; python_version < "3.10" in c:\anaconda3\lib\site-packages (from flask->jupyter_dash) (6.2.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->jupyter_dash) (2019.3.9)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.13.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.0.0)
# Requirement already satisfied: pickleshare in c:\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: decorator in c:\anaconda3\lib\site-packages (from ipython->jupyter_dash) (4.4.0)
# Requirement already satisfied: jedi>=0.10 in c:\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.13.3)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.0.9)
# Requirement already satisfied: pygments in c:\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.3.1)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.1)
# Requirement already satisfied: setuptools>=18.5 in c:\anaconda3\lib\site-packages (from ipython->jupyter_dash) (40.8.0)
# Requirement already satisfied: backcall in c:\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.1.0)
# Requirement already satisfied: traitlets>=4.2 in c:\anaconda3\lib\site-packages (from ipython->jupyter_dash) (4.3.2)
# Requirement already satisfied: tornado>=4.2 in c:\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.0.2)
# Requirement already satisfied: jupyter-client in c:\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.2.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from Jinja2>=3.0->flask->jupyter_dash) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->flask->jupyter_dash) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in c:\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->flask->jupyter_dash) (4.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (8.1.0)
# Requirement already satisfied: parso>=0.3.0 in c:\anaconda3\lib\site-packages (from jedi>=0.10->ipython->jupyter_dash) (0.3.4)
# Requirement already satisfied: wcwidth in c:\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->jupyter_dash) (0.1.7)
# Requirement already satisfied: ipython-genutils in c:\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.4.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.0)
# Requirement already satisfied: pyzmq>=13 in c:\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (18.0.0)
# Requirement already satisfied: httpx==0.20 in c:\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: dash in c:\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: plotly in c:\anaconda3\lib\site-packages (5.13.0)
# Requirement already satisfied: sniffio in c:\anaconda3\lib\site-packages (from httpx==0.20) (1.3.0)
# Requirement already satisfied: certifi in c:\anaconda3\lib\site-packages (from httpx==0.20) (2019.3.9)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\anaconda3\lib\site-packages (from httpx==0.20) (1.5.0)
# Requirement already satisfied: httpcore<0.14.0,>=0.13.3 in c:\anaconda3\lib\site-packages (from httpx==0.20) (0.13.7)
# Requirement already satisfied: charset-normalizer in c:\anaconda3\lib\site-packages (from httpx==0.20) (2.0.12)
# Requirement already satisfied: Flask>=1.0.4 in c:\anaconda3\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: dash-table==5.0.0 in c:\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\anaconda3\lib\site-packages (from plotly) (8.1.0)
# Requirement already satisfied: idna; extra == "idna2008" in c:\anaconda3\lib\site-packages (from rfc3986[idna2008]<2,>=1.3->httpx==0.20) (2.8)
# Requirement already satisfied: anyio==3.* in c:\anaconda3\lib\site-packages (from httpcore<0.14.0,>=0.13.3->httpx==0.20) (3.6.2)
# Requirement already satisfied: h11<0.13,>=0.11 in c:\anaconda3\lib\site-packages (from httpcore<0.14.0,>=0.13.3->httpx==0.20) (0.12.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0; python_version < "3.10" in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (6.2.0)
# Requirement already satisfied: click>=8.0 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in c:\anaconda3\lib\site-packages (from anyio==3.*->httpcore<0.14.0,>=0.13.3->httpx==0.20) (4.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\anaconda3\lib\site-packages (from Werkzeug>=2.2.2->Flask>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask>=1.0.4->dash) (3.15.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\anaconda3\lib\site-packages (from click>=8.0->Flask>=1.0.4->dash) (0.4.1)
# Requirement already satisfied: dash in c:\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: Flask>=1.0.4 in c:\anaconda3\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\anaconda3\lib\site-packages (from dash) (5.13.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: click>=8.0 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0; python_version < "3.10" in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (6.2.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.1.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\anaconda3\lib\site-packages (from click>=8.0->Flask>=1.0.4->dash) (0.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in c:\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask>=1.0.4->dash) (4.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask>=1.0.4->dash) (3.15.0)

# %%
# !wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
# Out:
# --2023-04-11 01:17:18--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2476 (2.4K) [text/csv]
# Saving to: 'spacex_launch_dash.csv'
#
#      0K ..                                                    100%  789M=0s
#
# 2023-04-11 01:17:20 (789 MB/s) - 'spacex_launch_dash.csv' saved [2476/2476]

# %%
# Import required libraries
import pandas as pd
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

#print(spacex_df['Launch Site'].unique())

# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                    {'label': 'All Sites', 'value': 'ALL'},
                                                    {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                    {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                    {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                    {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}],
                                             value='ALL',
                                             placeholder="Select a Launch Site here",
                                             searchable=True
                                            ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0, max=10000, step=1000,
                                                marks={0: '0', 100: '100'},
                                                value=[min_payload, max_payload]),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):    
    if entered_site == 'ALL':
        fig = px.pie(spacex_df, values='class', 
                     names='Launch Site', 
                     title='Total Success Launches By Site')        
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby('class').count().reset_index()        
        fig = px.pie(filtered_df, values='Unnamed: 0', 
                     names='class', 
                     title='Total Launches for site {}'.format(entered_site))        
        # return the outcomes piechart for a selected site
    return fig
        
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'), 
              Input(component_id="payload-slider", component_property="value"))
def get_scatter_chart(entered_site, payload_range):
    print('Params: {} {}'.format(entered_site, payload_range))
    if entered_site == 'ALL':
        filtered_df = spacex_df[(spacex_df['Payload Mass (kg)'] >= int(payload_range[0])) &
                                (spacex_df['Payload Mass (kg)'] <= int(payload_range[1]))
                               ] 
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')

        
    else:
        filtered_df = spacex_df[(spacex_df['Launch Site'] == entered_site) & 
                                (spacex_df['Payload Mass (kg)'] >= int(payload_range[0])) &
                                (spacex_df['Payload Mass (kg)'] <= int(payload_range[1]))
                               ]
        fig=px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],x='Payload Mass (kg)',y='class',color='Booster Version Category',title=f"Success count on Payload mass for site {entered_site}")
    
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
